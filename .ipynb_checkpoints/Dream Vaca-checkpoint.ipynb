# %% [markdown]
# # Clements dream Holiday
#
# ## In this notebook I will describe my dream holiday.

# %% [markdown]
# #### Table of Contents
#
# - [Activities](#first)
# - [Video](#second)

# %%
name=input('write a name: ')
# Out:
# write a name: Clement

# %% [markdown]
# ![11.SYS_107538.1.CAB.F.125.jpg](attachment:11.SYS_107538.1.CAB.F.125.jpg)

# %% [markdown]
# <img src='https://www.buscokite.com/wp-content/uploads/2019/06/spot-kitesurf-capetown-2.jpg'>

# %% [markdown]
# # *What I wanna do here (in Cape Town, South Africa)* <a class='anchor' id='first'></a>
#
# - Kitesurf
# - <font color="green">**Work with programming!**</font>
# - Do rock climbing

# %% [markdown]
# ### This is a video of kitesurfing in Cape Town (Seriously, check it out...) <a class='anchor' id='second'></a>
#
#
# <a href='https://www.youtube.com/watch?v=RAxwAwGxclo'>

# %% [markdown]
# [![Image alt text](https://img.youtube.com/vi/RAxwAwGxclo/0.jpg)](https://www.youtube.com/watch?v=RAxwAwGxclo)
